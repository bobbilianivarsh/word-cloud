# %%
pip install wordcloud
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/301.4 kB 393.8 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/301.4 kB 939.4 kB/s eta 0:00:01
#    ------------------------------------ --- 276.5/301.4 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 1.4 MB/s eta 0:00:00
# ...

# %%
# Create a list of word
input_words =("innovation, technology, data, science, future, learning,research, development,analytics, growth, solutions, creativity, discovery,progress, insight, collaboration, trends, advancement, success, strategy")

# %%
input_words
# Out:
# 'innovation, technology, data, science, future, learning,research, development,analytics, growth, solutions, creativity, discovery,progress, insight, collaboration, trends, advancement, success, strategy'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Create the wordcloud object
wordcloud = WordCloud(width=480, height=400, margin=2).generate(input_words)

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bicubic')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
input_words2 = ("imagination, art, design, inspiration, colors, creativity,expression,vision,dynamic,beauty,exceptional,technique,concetional,originally,ideas,aesthetic,innovation,style")

# %%
wordcloud2 = WordCloud(width=700, height=500, margin=50).generate(input_words2)

# %%
plt.imshow(wordcloud2, interpolation='bicubic')
plt.axis('on') # Shows axis
plt.margins(x=20, y=10) # horizontal and vertical margin (padding)
plt.show()

# %%
input_words3=("Viratkohli,Shreyas iyer,Riyanparag,MDsiraj,Rohit,surya,ishan,Maxi,ABd,Rajat,Anivarsh,Hardik,Gill,Faf,Shanthan,Warner,willjacks")

# %%
input_words3
# Out:
# 'Viratkohli,Shreyas iyer,Riyanparag,MDsiraj,Rohit,surya,ishan,Maxi,ABd,Rajat,Anivarsh,Hardik,Gill,Faf,Shanthan,Warner,willjacks'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(width=400, height=360, margin=2).generate(input_words3)

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bicubic')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()
